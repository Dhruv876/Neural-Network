# %% [markdown]
# # DataSet Exploration
#
# https://www.kaggle.com/harlfoxem/housesalesprediction

# %% [markdown]
# # Feature Columns
#
# id - Unique ID for each home sold
#
# date - Date of the home sale
#
# price - Price of each home sold
#
# bedrooms - Number of bedrooms
#
# bathrooms - Number of bathrooms, where .5 accounts for a room with a toilet but no shower
#
# sqft_living - Square footage of the apartments interior living space
#
# sqft_lot - Square footage of the land space
#
# floors - Number of floors
#
# waterfront - A dummy variable for whether the apartment was overlooking the waterfront or not
#
# view - An index from 0 to 4 of how good the view of the property was
#
# condition - An index from 1 to 5 on the condition of the apartment,
#
# grade - An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
#
# sqft_above - The square footage of the interior housing space that is above ground level
#
# sqft_basement - The square footage of the interior housing space that is below ground level
#
# yr_built - The year the house was initially built
#
# yr_renovated - The year of the house’s last renovation
#
# zipcode - What zipcode area the house is in
#
# lat - Lattitude
#
# long - Longitude
#
# sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
#
# sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# now we wheck null values or missing values
#df.isnull()
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null int64
# view             21597 non-null int64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null int64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null int64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df['price'].head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df['price'])

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['bedrooms'])

# %%
# now we check correlation
#highest correlation
df.corr()['price']
# Out:
# id              -0.016772
# price            1.000000
# bedrooms         0.308787
# bathrooms        0.525906
# sqft_living      0.701917
# sqft_lot         0.089876
# floors           0.256804
# waterfront       0.266398
# view             0.397370
# condition        0.036056
# grade            0.667951
# sqft_above       0.605368
# sqft_basement    0.323799
# yr_built         0.053953
# yr_renovated     0.126424
# zipcode         -0.053402
# lat              0.306692
# long             0.022036
# sqft_living15    0.585241
# sqft_lot15       0.082845
# Name: price, dtype: float64

# %%
# the sqft_living has highest correlation
# through this we check the highest correlation line

plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='sqft_living',data=df)

# %%
#plt.figure(figsize=(10,6))
#sns.boxplot(x='price',y='bedrooms',data=df)

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='lat',data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='long',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',hue='price',data=df)

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
# we are taking 0.01% of df
len(df)*0.01
# Out:
# 215.97

# %%
df.iloc[216]
# Out:
# id                46100204
# date             2/21/2015
# price             1.51e+06
# bedrooms                 5
# bathrooms                3
# sqft_living           3300
# sqft_lot             33474
# floors                   1
# waterfront               0
# view                     3
# condition                3
# grade                    9
# sqft_above            1870
# sqft_basement         1430
# yr_built              1957
# yr_renovated          1991
# zipcode              98040
# lat                47.5673
# long               -122.21
# sqft_living15         3836
# sqft_lot15           20953
# Name: 216, dtype: object

# %%
non_top_1_per = df.sort_values('price',ascending=False).iloc[216:]

# %%
non_top_1_per
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',hue='price',data=non_top_1_per,edgecolor=None,alpha=0.2,palette='RdYlGn')

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# we dont need id column

df=df.drop('id',axis=1)

# %%
# we can change date column to pandas datetime object

df['date'] = pd.to_datetime(df['date'])

# %%
df.head(2)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639

# %%
# we can extract month and year

df['year'] = df['date'].apply(lambda date : date.year)
df['month'] = df['date'].apply(lambda date : date.month)

# and remove the date column

df=df.drop('date',axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
plt.figure(figsize=(12,8))

sns.boxplot(x='month',y='price',data=df)

# %%
df.groupby(['month']).mean()['price'].plot()

# %%
plt.figure(figsize=(12,8))

sns.boxplot(x='year',y='price',data=df)

# %%
df.groupby(['year']).mean()['price'].plot()

# %%
df['zipcode'].value_counts()
# we have only 70 unique values in zipcode
# so we can remove zipcode
df = df.drop('zipcode',axis=1)
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %% [markdown]
# # Train/Test split

# %%
# now we will train test split

X = df.drop('price',axis=1).values
y = df['price']

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Scaling of data

# %%
# now we will do scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 19)

# %% [markdown]
# # Training of model

# %%
from tensorflow.kerasas.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=400)
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 2s 162us/sample - loss: 430236869192.7170 - val_loss: 418902563832.4148
# Epoch 2/400
# 15117/15117 [==============================] - 0s 31us/sample - loss: 429139333125.1481 - val_loss: 415193067004.2074
# Epoch 3/400
# 15117/15117 [==============================] - 1s 36us/sample - loss: 414862443881.1129 - val_loss: 383134971565.1951
# Epoch 4/400
# 15117/15117 [==============================] - 1s 39us/sample - loss: 347332885655.5306 - val_loss: 273941948896.3951
# Epoch 5/400
# 15117/15117 [==============================] - 1s 34us/sample - loss: 206471455232.2371 - val_loss: 131142615970.4494
# Epoch 6/400
# 15117/15117 [==============================] - 1s 36us/sample - loss: 110650015571.6738 - val_loss: 96128262002.4099
# Epoch 7/400
# 15117/15117 [==============================] - 1s 38us/sample - loss: 98487962861.1518 - val_loss: 94364688798.6568
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#              loss      val_loss
# 0    4.302369e+11  4.189026e+11
# 1    4.291393e+11  4.151931e+11
# 2    4.148624e+11  3.831350e+11
# 3    3.473329e+11  2.739419e+11
# 4    2.064715e+11  1.311426e+11
# ..            ...           ...
# 395  2.851077e+10  2.616287e+10
# 396  2.850197e+10  2.615978e+10
# 397  2.850213e+10  2.616042e+10
# 398  2.848949e+10  2.618256e+10
# 399  2.851598e+10  2.612001e+10
#
# [400 rows x 2 columns]

# %%
losses.plot()

# %% [markdown]
# # Evaluation and Predictions

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 161616.86720750722

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 99953.16068552276

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8030467818706383

# %%
df['price'].mean()
# Out:
# 540296.5735055795

# %%
df['price'].median()
# Out:
# 450000.0

# %%
df.describe()['price']
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
errors = y_test.values.reshape(6480,1) - predictions

# %%
plt.figure(figsize=(8,6))
sns.distplot(errors)

# %% [markdown]
# # Check our model prediction with first value of df

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
# transform and scaling the value
# and then we reshaped according to the model
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182]])

# %%
model.predict(single_house)
# Out:
# array([[285871.22]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price            221900.0000
# bedrooms              3.0000
# bathrooms             1.0000
# sqft_living        1180.0000
# sqft_lot           5650.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1180.0000
# sqft_basement         0.0000
# yr_built           1955.0000
# yr_renovated          0.0000
# lat                  47.5112
# long               -122.2570
# sqft_living15      1340.0000
# sqft_lot15         5650.0000
# year               2014.0000
# month                10.0000
# Name: 0, dtype: float64
